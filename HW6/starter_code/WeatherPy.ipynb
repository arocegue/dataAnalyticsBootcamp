# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "q=" + city + "&appid=" + weather_api_key + "&units=" + units
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']# YOUR CODE HERE
        city_lng = city_weather['coord']['lon']# YOUR CODE HERE
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity'] # YOUR CODE HERE
        city_clouds = city_weather['clouds']['all'] # YOUR CODE HERE
        city_wind = city_weather['wind']['speed'] # YOUR CODE HERE
        city_country = city_weather['sys']['country'] # YOUR CODE HERE
        city_date = city_weather['dt'] # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mitu
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | irymple
# Processing Record 4 of Set 1 | kone
# Processing Record 5 of Set 1 | majuro
# Processing Record 6 of Set 1 | coquimbo
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | nova xavantina
# Processing Record 10 of Set 1 | pauini
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | margate
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | vadso
# Processing Record 15 of Set 1 | aldinga beach
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | hawaiian paradise park
# Processing Record 18 of Set 1 | margaret river
# Processing Record 19 of Set 1 | aasiaat
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | buka
# Processing Record 22 of Set 1 | bubaque
# Processing Record 23 of Set 1 | lautoka
# Processing Record 24 of Set 1 | qaqortoq
# Processing Record 25 of Set 1 | atafu village
# Processing Record 26 of Set 1 | udachny
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | miyako
# Processing Record 29 of Set 1 | kirakira
# Processing Record 30 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 31 of Set 1 | kapuskasing
# Processing Record 32 of Set 1 | ust-nera
# Processing Record 33 of Set 1 | fort bragg
# Processing Record 34 of Set 1 | keflavik
# Processing Record 35 of Set 1 | salinopolis
# Processing Record 36 of Set 1 | sitka
# Processing Record 37 of Set 1 | tarifa
# Processing Record 38 of Set 1 | vilyuysk
# Processing Record 39 of Set 1 | nemuro
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | carbonear
# Processing Record 43 of Set 1 | altamira
# Processing Record 44 of Set 1 | ghoti budrukh
# Processing Record 45 of Set 1 | waitangi
# Processing Record 46 of Set 1 | christchurch
# Processing Record 47 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | medias
# Processing Record 50 of Set 1 | roosevelt
# Processing Record 0 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 2 | port-aux-francais
# Processing Record 2 of Set 2 | pariaman
# Processing Record 3 of Set 2 | priargunsk
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | mazatlan
# Processing Record 6 of Set 2 | prince rupert
# Processing Record 7 of Set 2 | kodiak
# Processing Record 8 of Set 2 | santa terezinha
# Processing Record 9 of Set 2 | kingston
# Processing Record 10 of Set 2 | grytviken
# Processing Record 11 of Set 2 | bilibino
# Processing Record 12 of Set 2 | inarajan village
# Processing Record 13 of Set 2 | la sarre
# Processing Record 14 of Set 2 | san luis de la loma
# Processing Record 15 of Set 2 | anadyr
# Processing Record 16 of Set 2 | riviere-du-loup
# Processing Record 17 of Set 2 | la foa
# Processing Record 18 of Set 2 | uturoa
# Processing Record 19 of Set 2 | susuman
# Processing Record 20 of Set 2 | mekhe
# Processing Record 21 of Set 2 | zouerate
# Processing Record 22 of Set 2 | vredendal
# Processing Record 23 of Set 2 | colipapa
# Processing Record 24 of Set 2 | meadow lake
# Processing Record 25 of Set 2 | bam
# Processing Record 26 of Set 2 | palmer
# Processing Record 27 of Set 2 | invercargill
# Processing Record 28 of Set 2 | warren
# Processing Record 29 of Set 2 | puerto natales
# Processing Record 30 of Set 2 | vila franca do campo
# Processing Record 31 of Set 2 | ushuaia
# Processing Record 32 of Set 2 | minas de marcona
# Processing Record 33 of Set 2 | crane
# Processing Record 34 of Set 2 | gashua
# Processing Record 35 of Set 2 | ebolowa
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | valdivia
# Processing Record 40 of Set 2 | rundu
# Processing Record 41 of Set 2 | mizdah
# Processing Record 42 of Set 2 | darwin
# Processing Record 43 of Set 2 | horodnya
# Processing Record 44 of Set 2 | saint-pierre
# Processing Record 45 of Set 2 | naracoorte
# Processing Record 46 of Set 2 | goz beida
# Processing Record 47 of Set 2 | colonia
# Processing Record 48 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 49 of Set 2 | antonio enes
# Processing Record 0 of Set 3 | port lincoln
# Processing Record 1 of Set 3 | iskateley
# Processing Record 2 of Set 3 | fada
# Processing Record 3 of Set 3 | chardara
# Processing Record 4 of Set 3 | bamboo flat
# Processing Record 5 of Set 3 | nova sintra
# Processing Record 6 of Set 3 | blackmans bay
# Processing Record 7 of Set 3 | badger
# Processing Record 8 of Set 3 | saint-florent-sur-cher
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | al hudaydah
# Processing Record 11 of Set 3 | punaauia
# Processing Record 12 of Set 3 | rongelap
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | isafjordur
# Processing Record 15 of Set 3 | coahuayana de hidalgo
# Processing Record 16 of Set 3 | tadine
# Processing Record 17 of Set 3 | tchintabaraden
# Processing Record 18 of Set 3 | yangor
# City not found. Skipping...
# Processing Record 19 of Set 3 | hiratacho
# Processing Record 20 of Set 3 | grootfontein
# Processing Record 21 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 22 of Set 3 | huarmey
# Processing Record 23 of Set 3 | chu
# Processing Record 24 of Set 3 | codrington
# Processing Record 25 of Set 3 | port elizabeth
# Processing Record 26 of Set 3 | akureyri
# Processing Record 27 of Set 3 | port mathurin
# Processing Record 28 of Set 3 | hami
# Processing Record 29 of Set 3 | velyka dymerka
# Processing Record 30 of Set 3 | porangatu
# Processing Record 31 of Set 3 | solleftea
# Processing Record 32 of Set 3 | papatowai
# Processing Record 33 of Set 3 | klyuchi
# Processing Record 34 of Set 3 | weno
# Processing Record 35 of Set 3 | dryden
# Processing Record 36 of Set 3 | lebu
# Processing Record 37 of Set 3 | shitanjing
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | altai
# Processing Record 40 of Set 3 | shingu
# Processing Record 41 of Set 3 | st. john's
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | trincomalee
# Processing Record 44 of Set 3 | kotel'nikovo
# Processing Record 45 of Set 3 | puerto ayora
# Processing Record 46 of Set 3 | howard springs
# Processing Record 47 of Set 3 | santa rosa misiones
# Processing Record 48 of Set 3 | porto novo
# Processing Record 49 of Set 3 | ugoofaaru
# Processing Record 0 of Set 4 | berezovyy
# Processing Record 1 of Set 4 | rengasdengklok
# Processing Record 2 of Set 4 | namdrik
# Processing Record 3 of Set 4 | shizunai-furukawacho
# Processing Record 4 of Set 4 | katabu
# Processing Record 5 of Set 4 | chadron
# Processing Record 6 of Set 4 | shimanovsk
# Processing Record 7 of Set 4 | queenstown
# Processing Record 8 of Set 4 | dadonghai
# City not found. Skipping...
# Processing Record 9 of Set 4 | hermanus
# Processing Record 10 of Set 4 | wuwei
# Processing Record 11 of Set 4 | shimoda
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | quelimane
# Processing Record 14 of Set 4 | nazret
# Processing Record 15 of Set 4 | richlands
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | konde
# Processing Record 18 of Set 4 | olindina
# Processing Record 19 of Set 4 | kurumkan
# Processing Record 20 of Set 4 | olonkinbyen
# Processing Record 21 of Set 4 | sao joao da barra
# Processing Record 22 of Set 4 | san antonio de pale
# Processing Record 23 of Set 4 | es castell
# Processing Record 24 of Set 4 | aras-asan
# Processing Record 25 of Set 4 | nadym
# Processing Record 26 of Set 4 | road town
# Processing Record 27 of Set 4 | el charco
# Processing Record 28 of Set 4 | ballina
# Processing Record 29 of Set 4 | sillamae
# Processing Record 30 of Set 4 | george town
# Processing Record 31 of Set 4 | ekibastuz
# Processing Record 32 of Set 4 | say
# Processing Record 33 of Set 4 | tinana
# City not found. Skipping...
# Processing Record 34 of Set 4 | kattivakkam
# Processing Record 35 of Set 4 | hithadhoo
# Processing Record 36 of Set 4 | singaraja
# Processing Record 37 of Set 4 | tura
# Processing Record 38 of Set 4 | ebaye
# Processing Record 39 of Set 4 | gadzhiyevo
# Processing Record 40 of Set 4 | westport
# Processing Record 41 of Set 4 | enewetak
# Processing Record 42 of Set 4 | nar'yan-mar
# Processing Record 43 of Set 4 | moscow
# Processing Record 44 of Set 4 | tolanaro
# Processing Record 45 of Set 4 | pasuquin
# Processing Record 46 of Set 4 | niedergorsdorf
# Processing Record 47 of Set 4 | knysna
# Processing Record 48 of Set 4 | berowra heights
# Processing Record 49 of Set 4 | santana de parnaiba
# Processing Record 0 of Set 5 | padampur
# Processing Record 1 of Set 5 | lappeenranta
# Processing Record 2 of Set 5 | flying fish cove
# Processing Record 3 of Set 5 | lata
# Processing Record 4 of Set 5 | san antonio
# Processing Record 5 of Set 5 | polyarnyy
# Processing Record 6 of Set 5 | santa cruz
# Processing Record 7 of Set 5 | mhamid
# Processing Record 8 of Set 5 | el porvenir
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | yeongam
# City not found. Skipping...
# Processing Record 11 of Set 5 | whitehorse
# Processing Record 12 of Set 5 | srandakan
# Processing Record 13 of Set 5 | khilok
# Processing Record 14 of Set 5 | lihue
# Processing Record 15 of Set 5 | touros
# Processing Record 16 of Set 5 | burang
# Processing Record 17 of Set 5 | mugia
# Processing Record 18 of Set 5 | sur
# Processing Record 19 of Set 5 | temiskaming shores
# Processing Record 20 of Set 5 | dudinka
# Processing Record 21 of Set 5 | belomorsk
# Processing Record 22 of Set 5 | khandyga
# Processing Record 23 of Set 5 | bayji
# Processing Record 24 of Set 5 | virac
# Processing Record 25 of Set 5 | ahmadpur
# Processing Record 26 of Set 5 | puerto baquerizo moreno
# Processing Record 27 of Set 5 | karmaskaly
# Processing Record 28 of Set 5 | west island
# Processing Record 29 of Set 5 | roma
# Processing Record 30 of Set 5 | andalgala
# Processing Record 31 of Set 5 | sittwe
# Processing Record 32 of Set 5 | nizhnevartovsk
# Processing Record 33 of Set 5 | kourou
# Processing Record 34 of Set 5 | kuanda
# Processing Record 35 of Set 5 | afaahiti
# Processing Record 36 of Set 5 | stanley
# Processing Record 37 of Set 5 | ghanzi
# Processing Record 38 of Set 5 | katsuren-haebaru
# Processing Record 39 of Set 5 | conde
# Processing Record 40 of Set 5 | walvis bay
# Processing Record 41 of Set 5 | nyachera
# Processing Record 42 of Set 5 | beinamar
# Processing Record 43 of Set 5 | selfoss
# Processing Record 44 of Set 5 | poulsbo
# Processing Record 45 of Set 5 | puerto deseado
# Processing Record 46 of Set 5 | newman
# Processing Record 47 of Set 5 | staranzano
# Processing Record 48 of Set 5 | chui
# Processing Record 49 of Set 5 | cumberland
# Processing Record 0 of Set 6 | myeik
# Processing Record 1 of Set 6 | tenno
# Processing Record 2 of Set 6 | port augusta
# Processing Record 3 of Set 6 | greymouth
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | nouadhibou
# Processing Record 6 of Set 6 | sept-iles
# Processing Record 7 of Set 6 | ayaguz
# City not found. Skipping...
# Processing Record 8 of Set 6 | xique xique
# Processing Record 9 of Set 6 | nkhata bay
# Processing Record 10 of Set 6 | taulaga
# Processing Record 11 of Set 6 | cafayate
# Processing Record 12 of Set 6 | vila do maio
# Processing Record 13 of Set 6 | ijuw
# City not found. Skipping...
# Processing Record 14 of Set 6 | terenozek
# Processing Record 15 of Set 6 | kittila
# Processing Record 16 of Set 6 | elliot lake
# Processing Record 17 of Set 6 | tamanrasset
# Processing Record 18 of Set 6 | kavaratti
# Processing Record 19 of Set 6 | mancora
# Processing Record 20 of Set 6 | jinxiang
# Processing Record 21 of Set 6 | utrik
# Processing Record 22 of Set 6 | labytnangi
# Processing Record 23 of Set 6 | whyalla stuart
# City not found. Skipping...
# Processing Record 24 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 25 of Set 6 | filey
# Processing Record 26 of Set 6 | mamuju
# Processing Record 27 of Set 6 | ihsaniye
# Processing Record 28 of Set 6 | tazovsky
# Processing Record 29 of Set 6 | kavalerovo
# Processing Record 30 of Set 6 | ormara
# Processing Record 31 of Set 6 | chonchi
# Processing Record 32 of Set 6 | kailua-kona
# Processing Record 33 of Set 6 | oum hadjer
# Processing Record 34 of Set 6 | san pedro
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | tralee
# Processing Record 37 of Set 6 | la passe
# Processing Record 38 of Set 6 | saue
# Processing Record 39 of Set 6 | mombetsu
# Processing Record 40 of Set 6 | sisimiut
# Processing Record 41 of Set 6 | arden-arcade
# Processing Record 42 of Set 6 | sim
# Processing Record 43 of Set 6 | podujeva
# Processing Record 44 of Set 6 | papao
# Processing Record 45 of Set 6 | tazacorte
# Processing Record 46 of Set 6 | manismata
# Processing Record 47 of Set 6 | barcelos
# Processing Record 48 of Set 6 | pico truncado
# Processing Record 49 of Set 6 | belyy yar
# Processing Record 0 of Set 7 | usinsk
# Processing Record 1 of Set 7 | isangel
# Processing Record 2 of Set 7 | ostersund
# Processing Record 3 of Set 7 | ingeniero jacobacci
# Processing Record 4 of Set 7 | barbacoas
# Processing Record 5 of Set 7 | bembereke
# Processing Record 6 of Set 7 | kimbe
# Processing Record 7 of Set 7 | vilyuchinsk
# Processing Record 8 of Set 7 | norfolk
# Processing Record 9 of Set 7 | bahia blanca
# Processing Record 10 of Set 7 | nova olimpia
# Processing Record 11 of Set 7 | wailua homesteads
# Processing Record 12 of Set 7 | gaspe
# Processing Record 13 of Set 7 | solnechnyy
# Processing Record 14 of Set 7 | nandikotkur
# Processing Record 15 of Set 7 | macon
# Processing Record 16 of Set 7 | hsinchu
# Processing Record 17 of Set 7 | al-`ula
# City not found. Skipping...
# Processing Record 18 of Set 7 | pangody
# Processing Record 19 of Set 7 | tindouf
# Processing Record 20 of Set 7 | sukumo
# Processing Record 21 of Set 7 | kristiansund
# Processing Record 22 of Set 7 | muroto-misakicho
# Processing Record 23 of Set 7 | santa marta
# Processing Record 24 of Set 7 | beyneu
# Processing Record 25 of Set 7 | det udom
# Processing Record 26 of Set 7 | taksimo
# Processing Record 27 of Set 7 | volosovo
# Processing Record 28 of Set 7 | lompoc
# Processing Record 29 of Set 7 | veraval
# Processing Record 30 of Set 7 | port saint john's
# Processing Record 31 of Set 7 | amol
# Processing Record 32 of Set 7 | abu qurqas
# Processing Record 33 of Set 7 | benghazi
# Processing Record 34 of Set 7 | al bawiti
# Processing Record 35 of Set 7 | alice springs
# Processing Record 36 of Set 7 | cole harbour
# Processing Record 37 of Set 7 | sabang
# Processing Record 38 of Set 7 | mount gambier
# Processing Record 39 of Set 7 | mermoz boabab
# Processing Record 40 of Set 7 | pandan
# Processing Record 41 of Set 7 | fort st. john
# Processing Record 42 of Set 7 | jonquiere
# Processing Record 43 of Set 7 | celestun
# Processing Record 44 of Set 7 | fort drum
# Processing Record 45 of Set 7 | santyoku
# Processing Record 46 of Set 7 | ad darb
# Processing Record 47 of Set 7 | igarka
# Processing Record 48 of Set 7 | gizo
# Processing Record 49 of Set 7 | bogale
# Processing Record 0 of Set 8 | howrah
# Processing Record 1 of Set 8 | santa ana
# Processing Record 2 of Set 8 | sao vicente
# Processing Record 3 of Set 8 | tromso
# Processing Record 4 of Set 8 | kousa
# Processing Record 5 of Set 8 | minot
# Processing Record 6 of Set 8 | kirishi
# Processing Record 7 of Set 8 | freetown
# Processing Record 8 of Set 8 | seguin
# Processing Record 9 of Set 8 | korla
# Processing Record 10 of Set 8 | corner brook
# Processing Record 11 of Set 8 | rumoi
# Processing Record 12 of Set 8 | verkhnevilyuysk
# Processing Record 13 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 14 of Set 8 | san juan de miraflores
# Processing Record 15 of Set 8 | sadjoavato
# City not found. Skipping...
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | whangarei
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | syktyvkar
# Processing Record 20 of Set 8 | tocopilla
# Processing Record 21 of Set 8 | nguigmi
# Processing Record 22 of Set 8 | kavieng
# Processing Record 23 of Set 8 | zhukovka
# Processing Record 24 of Set 8 | lerwick
# Processing Record 25 of Set 8 | nova vicosa
# Processing Record 26 of Set 8 | cill airne
# Processing Record 27 of Set 8 | port alfred
# Processing Record 28 of Set 8 | aitape
# Processing Record 29 of Set 8 | al mayadin
# Processing Record 30 of Set 8 | doctor arroyo
# Processing Record 31 of Set 8 | thunder bay
# Processing Record 32 of Set 8 | gilgit
# Processing Record 33 of Set 8 | angaur state
# Processing Record 34 of Set 8 | tete
# Processing Record 35 of Set 8 | hassi messaoud
# Processing Record 36 of Set 8 | qulsary
# Processing Record 37 of Set 8 | agua branca
# Processing Record 38 of Set 8 | kirensk
# Processing Record 39 of Set 8 | aykhal
# Processing Record 40 of Set 8 | carleton place
# Processing Record 41 of Set 8 | deniliquin
# Processing Record 42 of Set 8 | prado
# Processing Record 43 of Set 8 | la ronge
# Processing Record 44 of Set 8 | acapulco de juarez
# Processing Record 45 of Set 8 | jinghong
# Processing Record 46 of Set 8 | bluffton
# Processing Record 47 of Set 8 | haiku-pauwela
# Processing Record 48 of Set 8 | shizukuishi
# Processing Record 49 of Set 8 | cidade velha
# Processing Record 0 of Set 9 | constantia
# Processing Record 1 of Set 9 | aioun
# Processing Record 2 of Set 9 | kitimat
# Processing Record 3 of Set 9 | nukunonu
# City not found. Skipping...
# Processing Record 4 of Set 9 | la huacana
# Processing Record 5 of Set 9 | pakuranga
# Processing Record 6 of Set 9 | la'ie
# Processing Record 7 of Set 9 | moose jaw
# Processing Record 8 of Set 9 | murzuq
# Processing Record 9 of Set 9 | vorgashor
# Processing Record 10 of Set 9 | melfort
# Processing Record 11 of Set 9 | bu'aale
# Processing Record 12 of Set 9 | tidjikja
# Processing Record 13 of Set 9 | siderno
# Processing Record 14 of Set 9 | cannonvale
# Processing Record 15 of Set 9 | college
# Processing Record 16 of Set 9 | mujiayingzi
# Processing Record 17 of Set 9 | kirkland lake
# Processing Record 18 of Set 9 | tevragh zeina
# City not found. Skipping...
# Processing Record 19 of Set 9 | namibe
# Processing Record 20 of Set 9 | saipan
# Processing Record 21 of Set 9 | pangai
# Processing Record 22 of Set 9 | tsiroanomandidy
# Processing Record 23 of Set 9 | makhambet
# Processing Record 24 of Set 9 | kupang
# Processing Record 25 of Set 9 | saint-francois
# Processing Record 26 of Set 9 | toamasina
# Processing Record 27 of Set 9 | ambalangoda
# Processing Record 28 of Set 9 | chibougamau
# Processing Record 29 of Set 9 | san julian
# Processing Record 30 of Set 9 | richards bay
# Processing Record 31 of Set 9 | ishigaki
# Processing Record 32 of Set 9 | kashgar
# Processing Record 33 of Set 9 | tibati
# Processing Record 34 of Set 9 | dolzhanskaya
# Processing Record 35 of Set 9 | ecoporanga
# Processing Record 36 of Set 9 | tofol
# Processing Record 37 of Set 9 | cidreira
# Processing Record 38 of Set 9 | inhambane
# Processing Record 39 of Set 9 | qamdo
# Processing Record 40 of Set 9 | oranjemund
# Processing Record 41 of Set 9 | hammerfest
# Processing Record 42 of Set 9 | egilsstadir
# Processing Record 43 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 9 | lepsy
# Processing Record 45 of Set 9 | governor's harbour
# City not found. Skipping...
# Processing Record 46 of Set 9 | gujba
# Processing Record 47 of Set 9 | mahina
# Processing Record 48 of Set 9 | ola
# Processing Record 49 of Set 9 | floro
# Processing Record 0 of Set 10 | san andres
# Processing Record 1 of Set 10 | posto fiscal rolim de moura
# Processing Record 2 of Set 10 | fale old settlement
# Processing Record 3 of Set 10 | happy valley-goose bay
# Processing Record 4 of Set 10 | sombrerete
# Processing Record 5 of Set 10 | minas de matahambre
# City not found. Skipping...
# Processing Record 6 of Set 10 | semirara
# Processing Record 7 of Set 10 | ranohira
# City not found. Skipping...
# Processing Record 8 of Set 10 | anqing
# Processing Record 9 of Set 10 | mejit
# Processing Record 10 of Set 10 | borba
# Processing Record 11 of Set 10 | lembar
# City not found. Skipping...
# Processing Record 12 of Set 10 | nabire
# Processing Record 13 of Set 10 | ta`u
# Processing Record 14 of Set 10 | bangar
# Processing Record 15 of Set 10 | alpena
# Processing Record 16 of Set 10 | opuwo
# Processing Record 17 of Set 10 | ubinskoye
# Processing Record 18 of Set 10 | drabesi
# City not found. Skipping...
# Processing Record 19 of Set 10 | coracora
# Processing Record 20 of Set 10 | tommot
# Processing Record 21 of Set 10 | kariapatti
# Processing Record 22 of Set 10 | fort mcmurray
# Processing Record 23 of Set 10 | thurso
# Processing Record 24 of Set 10 | dalandzadgad
# Processing Record 25 of Set 10 | hohhot
# Processing Record 26 of Set 10 | mbalmayo
# Processing Record 27 of Set 10 | vila velha
# Processing Record 28 of Set 10 | khorramabad
# Processing Record 29 of Set 10 | waspan
# Processing Record 30 of Set 10 | malango
# Processing Record 31 of Set 10 | tangalle
# Processing Record 32 of Set 10 | nykvarn
# Processing Record 33 of Set 10 | uspenskoye
# Processing Record 34 of Set 10 | okondja
# Processing Record 35 of Set 10 | zhezqazghan
# Processing Record 36 of Set 10 | kharp
# Processing Record 37 of Set 10 | prince george
# Processing Record 38 of Set 10 | gambiran satu
# Processing Record 39 of Set 10 | auki
# Processing Record 40 of Set 10 | tanjung pandan
# Processing Record 41 of Set 10 | shangmei
# Processing Record 42 of Set 10 | nushki
# Processing Record 43 of Set 10 | acarau
# Processing Record 44 of Set 10 | palangkaraya
# Processing Record 45 of Set 10 | ternate
# Processing Record 46 of Set 10 | sehwan
# Processing Record 47 of Set 10 | kalur kot
# Processing Record 48 of Set 10 | teplyk
# Processing Record 49 of Set 10 | boyalik
# Processing Record 0 of Set 11 | 'ibri
# City not found. Skipping...
# Processing Record 1 of Set 11 | mariinsk
# Processing Record 2 of Set 11 | alofi
# Processing Record 3 of Set 11 | brandon
# Processing Record 4 of Set 11 | cabo san lucas
# Processing Record 5 of Set 11 | forster
# Processing Record 6 of Set 11 | salym
# Processing Record 7 of Set 11 | banff
# Processing Record 8 of Set 11 | nantucket
# Processing Record 9 of Set 11 | abepura
# Processing Record 10 of Set 11 | mossel bay
# Processing Record 11 of Set 11 | maun
# Processing Record 12 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 13 of Set 11 | chegdomyn
# Processing Record 14 of Set 11 | mount pearl
# Processing Record 15 of Set 11 | jinan
# Processing Record 16 of Set 11 | jungapeo de juarez
# Processing Record 17 of Set 11 | esmeraldas
# Processing Record 18 of Set 11 | leon
# Processing Record 19 of Set 11 | mar del plata
# Processing Record 20 of Set 11 | peace river
# Processing Record 21 of Set 11 | archangelos
# Processing Record 22 of Set 11 | quellon
# Processing Record 23 of Set 11 | puerto armuelles
# Processing Record 24 of Set 11 | vallenar
# Processing Record 25 of Set 11 | nhamunda
# Processing Record 26 of Set 11 | chinchilla
# Processing Record 27 of Set 11 | kyren
# Processing Record 28 of Set 11 | najran
# Processing Record 29 of Set 11 | toliara
# Processing Record 30 of Set 11 | taco pozo
# Processing Record 31 of Set 11 | thinadhoo
# Processing Record 32 of Set 11 | ladysmith
# Processing Record 33 of Set 11 | carolina beach
# Processing Record 34 of Set 11 | franklin park
# Processing Record 35 of Set 11 | coro
# Processing Record 36 of Set 11 | jining
# Processing Record 37 of Set 11 | ulsan
# Processing Record 38 of Set 11 | broome
# Processing Record 39 of Set 11 | yemetsk
# Processing Record 40 of Set 11 | amahai
# Processing Record 41 of Set 11 | ulan bator
# Processing Record 42 of Set 11 | tual
# Processing Record 43 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 44 of Set 11 | fortuna
# Processing Record 45 of Set 11 | praia da vitoria
# Processing Record 46 of Set 11 | broken hill
# Processing Record 47 of Set 11 | kamaishi
# Processing Record 48 of Set 11 | abdanan
# Processing Record 49 of Set 11 | charlottetown
# Processing Record 0 of Set 12 | tucupita
# Processing Record 1 of Set 12 | nagqu
# Processing Record 2 of Set 12 | pacific grove
# Processing Record 3 of Set 12 | askoy
# Processing Record 4 of Set 12 | beira
# Processing Record 5 of Set 12 | salekhard
# Processing Record 6 of Set 12 | robore
# Processing Record 7 of Set 12 | fiambala
# Processing Record 8 of Set 12 | etowah
# Processing Record 9 of Set 12 | kendari
# Processing Record 10 of Set 12 | quesnel
# Processing Record 11 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 12 of Set 12 | baijiantan
# Processing Record 13 of Set 12 | shiqian
# Processing Record 14 of Set 12 | olyokminsk
# Processing Record 15 of Set 12 | minacu
# City not found. Skipping...
# Processing Record 16 of Set 12 | libreville
# Processing Record 17 of Set 12 | kempsey
# Processing Record 18 of Set 12 | williams lake
# Processing Record 19 of Set 12 | tarko-sale
# Processing Record 20 of Set 12 | port macquarie
# Processing Record 21 of Set 12 | belmonte
# Processing Record 22 of Set 12 | ghat
# Processing Record 23 of Set 12 | sancaktepe
# Processing Record 24 of Set 12 | ascension
# Processing Record 25 of Set 12 | burutu
# Processing Record 26 of Set 12 | veyrier
# Processing Record 27 of Set 12 | urucara
# Processing Record 28 of Set 12 | bayanhongor
# Processing Record 29 of Set 12 | priozersk
# Processing Record 30 of Set 12 | konce
# Processing Record 31 of Set 12 | itoman
# Processing Record 32 of Set 12 | menaka
# Processing Record 33 of Set 12 | mogadishu
# Processing Record 34 of Set 12 | yomju-up
# Processing Record 35 of Set 12 | mahdia
# Processing Record 36 of Set 12 | champerico
# Processing Record 37 of Set 12 | north battleford
# Processing Record 38 of Set 12 | myitkyina
# Processing Record 39 of Set 12 | hotan
# Processing Record 40 of Set 12 | el calafate
# Processing Record 41 of Set 12 | konarka
# Processing Record 42 of Set 12 | marsh harbour
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          mitu   1.1983  -70.1733     22.42        99         100
# 1  longyearbyen  78.2186   15.6401     -2.09        54           0
# 2       irymple -34.2500  142.1667     12.83        88          94
# 3          kone -21.0595  164.8658     25.85        51          10
# 4        majuro   7.0897  171.3803     30.98        74          75
#
#    Wind Speed Country        Date
# 0        0.85      CO  1685234434
# 1        3.09      SJ  1685234435
# 2        3.58      AU  1685234435
# 3        3.12      NC  1685234436
# 4        2.06      MH  1685234437

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                mitu   1.1983  -70.1733     22.42        99         100
# 1        longyearbyen  78.2186   15.6401     -2.09        54           0
# 2             irymple -34.2500  142.1667     12.83        88          94
# 3                kone -21.0595  164.8658     25.85        51          10
# 4              majuro   7.0897  171.3803     30.98        74          75
#
#          Wind Speed Country        Date
# City_ID
# 0              0.85      CO  1685234434
# 1              3.09      SJ  1685234435
# 2              3.58      AU  1685234435
# 3              3.12      NC  1685234436
# 4              2.06      MH  1685234437

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
from datetime import datetime

approx_date = datetime.utcfromtimestamp(city_data_df['Date'][0]).strftime('%Y-%m-%d')
city_data_df.plot('Lat', 'Max Temp', kind='scatter', grid=True, xlabel='Latitude', ylabel='Max Temperature (C)', title=f'City Max Latitude Vs. Temperature ({approx_date})', edgecolors='black', alpha=0.75, s=30)

# Incorporate the other graph properties

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot('Lat', 'Humidity', kind='scatter', grid=True, xlabel='Latitude', ylabel='Humidity (%)', title=f'City Max Latitude Vs. Humidity ({approx_date})', edgecolors='black', alpha=0.75, s=30)


# Incorporate the other graph properties

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot('Lat', 'Cloudiness', kind='scatter', grid=True, xlabel='Latitude', ylabel='Cloudiness (%)', title=f'City Max Latitude Vs. Cloudiness ({approx_date})', edgecolors='black', alpha=0.75, s=30)

# Incorporate the other graph properties

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot('Lat', 'Wind Speed', kind='scatter', grid=True, xlabel='Latitude', ylabel='Cloudiness (%)', title=f'City Max Latitude Vs. Wind Speed ({approx_date})', edgecolors='black', alpha=0.75, s=30)


# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plotLinearRegression(df, x, y, str1, str2):
    df.plot(x, y, kind='scatter', grid=True, xlabel=str1, ylabel=str2, title=f'City Max Latitude Vs. {str2} ({approx_date})', edgecolors='black', alpha=0.75, s=30)
    #y=mx+b
    slope, intercept, r, p, se = linregress(df[x], df[y])
    line = slope * df[x] + intercept
    plt.plot(df[x], line,'r', linewidth=2)
    
    # # Save the figure
    # plt.savefig("../output_data/Fig4.png")
    print(f"The r-value is: {r}")
    plt.annotate(f'y = {slope:.02f}x + {intercept:.02f}', xy=(5,85), xycoords='axes points', color='black', size=16, ha='left')
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                mitu   1.1983  -70.1733     22.42        99         100
# 1        longyearbyen  78.2186   15.6401     -2.09        54           0
# 4              majuro   7.0897  171.3803     30.98        74          75
# 10             bethel  41.3712  -73.4140     19.46        50           2
# 11            margate  51.3813    1.3862     11.06        89           9
#
#          Wind Speed Country        Date
# City_ID
# 0              0.85      CO  1685234434
# 1              3.09      SJ  1685234435
# 4              2.06      MH  1685234437
# 10             0.45      US  1685234159
# 11             1.79      GB  1685234440

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                            irymple -34.2500  142.1667     12.83        88
# 3                               kone -21.0595  164.8658     25.85        51
# 5                           coquimbo -29.9533  -71.3436     13.85        88
# 6                          adamstown -25.0660 -130.1015     22.30        73
# 7        edinburgh of the seven seas -37.0676  -12.3116     12.61        55
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                94        3.58      AU  1685234435
# 3                10        3.12      NC  1685234436
# 5                 0        2.06      CL  1685234183
# 6                35       10.99      PN  1685234437
# 7                75        3.35      SH  1685234438

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plotLinearRegression(northern_hemi_df, 'Lat', 'Max Temp', 'Latitude', 'Max Temp')
# Out:
# The r-value is: -0.7922050078439777

# %%
# Linear regression on Southern Hemisphere
plotLinearRegression(southern_hemi_df, 'Lat', 'Max Temp', 'Latitude', 'Max Temp')
# Out:
# The r-value is: 0.8280280874232381

# %% [markdown]
# **Discussion about the linear relationship:** The Linear Relationship between the two hemispheres is that the farther you go from the origin of latitude 0, max temperature decreases. And the two meet at its max temp peak at latitude 0 where the slope/vertex is 0. The r-value in the two hemispheres, confirms there is a significant correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plotLinearRegression(northern_hemi_df, 'Lat', 'Humidity', 'Latitude', 'Humidity')
# Out:
# The r-value is: -0.1331123460706087

# %%
# Southern Hemisphere
plotLinearRegression(southern_hemi_df, 'Lat', 'Humidity', 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.1910251767974326

# %% [markdown]
# **Discussion about the linear relationship:** The Linear Relationship between the two hemispheres is that the farther you go from the origin of latitude 0, humidity MAY decrease slightly. The difference isnt as big as temperature drop as we've seen before but it does decrease from the point of origin a bit. R-Value is very minimal with some correlation

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plotLinearRegression(northern_hemi_df, 'Lat', 'Cloudiness', 'Latitude', 'Cloudiness')
# Out:
# The r-value is: -0.09562803675571852

# %%
# Southern Hemisphere
plotLinearRegression(southern_hemi_df, 'Lat', 'Cloudiness', 'Latitude', 'Cloudiness')
# Out:
# The r-value is: -0.009239404070361789

# %% [markdown]
# **Discussion about the linear relationship:** There is no linear relationship between Latitude and cloudiness. Each position seems to be volatile and not consistent enough to make a determination. R-value is also closer to zero confirm there is no certain correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plotLinearRegression(northern_hemi_df, 'Lat', 'Wind Speed', 'Latitude', 'Wind Speed')
# Out:
# The r-value is: 0.05450844837195043

# %%
# Southern Hemisphere
plotLinearRegression(southern_hemi_df, 'Lat', 'Wind Speed', 'Latitude', 'Wind Speed')
# Out:
# The r-value is: -0.16920771828971828

# %% [markdown]
# **Discussion about the linear relationship:** The is no correlation between latitude and windspeed. The R-Value in the northern hemisphere is closer to 0 which demonstrates no correlation between the two factors and in the souther hemisphere it becomes slightly more correlated but not enough to say it is significant.
